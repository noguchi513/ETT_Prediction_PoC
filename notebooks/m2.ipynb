# %%
# !pip install --upgrade torch

# %%
# Torch確認（Colab標準）
import torch
import torch.nn as nn

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch version: 2.10.0+cu128
# CUDA available: True

# %%
# ============================================================
# ETTm2 PatchTST + RevIN 改良完全版
# （baseline維持 / ジャンプ抑制 / 振幅改善）
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# ---------------------------
# 再現性
# ---------------------------
torch.manual_seed(42)
np.random.seed(42)

device = "cuda" if torch.cuda.is_available() else "cpu"

# ============================================================
# データ読み込み
# ============================================================
df = pd.read_csv("../data/ETTm2.csv")
df["date"] = pd.to_datetime(df["date"])
df = df.set_index("date")

target_col = "OT"
target_idx = df.columns.get_loc(target_col)

# ---------------------------
# Split
# ---------------------------
n = len(df)
train_end = int(n * 0.7)
val_end   = int(n * 0.85)

train_df = df.iloc[:train_end].copy()
val_df   = df.iloc[train_end:val_end].copy()
test_df  = df.iloc[val_end:].copy()

# ---------------------------
# StandardScaler
# ---------------------------
scaler = StandardScaler()

train_df.loc[:] = scaler.fit_transform(train_df)
val_df.loc[:]   = scaler.transform(val_df)
test_df.loc[:]  = scaler.transform(test_df)

# ============================================================
# RevIN
# ============================================================
class RevIN(nn.Module):
    def __init__(self, num_features, eps=1e-5):
        super().__init__()
        self.eps = eps
        self.gamma = nn.Parameter(torch.ones(1, 1, num_features))
        self.beta  = nn.Parameter(torch.zeros(1, 1, num_features))

    def forward(self, x, mode):

        if mode == "norm":
            self.mean = x.mean(1, keepdim=True)
            self.std  = x.std(1, keepdim=True)

            x = (x - self.mean) / (self.std + self.eps)
            return x * self.gamma + self.beta

        elif mode == "denorm":
            x = (x - self.beta) / self.gamma
            return x * (self.std + self.eps) + self.mean

# ============================================================
# Dataset
# ============================================================
INPUT_LEN = 672
PRED_LEN  = 672

class TimeSeriesDataset(Dataset):
    def __init__(self, data):
        self.data = data.values.astype(np.float32)

    def __len__(self):
        return len(self.data) - INPUT_LEN - PRED_LEN

    def __getitem__(self, idx):

        seq = self.data[idx : idx + INPUT_LEN + PRED_LEN]

        x = seq[:INPUT_LEN]
        y = seq[INPUT_LEN:, target_idx]

        return torch.tensor(x), torch.tensor(y)

train_ds = TimeSeriesDataset(train_df)
val_ds   = TimeSeriesDataset(val_df)
test_ds  = TimeSeriesDataset(test_df)

train_loader = DataLoader(train_ds, 64, shuffle=False)
val_loader   = DataLoader(val_ds, 64)
test_loader  = DataLoader(test_ds, 64)

# ============================================================
# Patch Embedding
# ============================================================
class PatchEmbedding(nn.Module):
    def __init__(self, in_dim, patch_len, d_model):
        super().__init__()
        self.patch_len = patch_len
        self.proj = nn.Linear(in_dim * patch_len, d_model)

    def forward(self, x):

        B, L, C = x.shape
        num_patch = L // self.patch_len

        x = x[:, : num_patch * self.patch_len]

        x = x.reshape(
            B,
            num_patch,
            self.patch_len * C
        )

        return self.proj(x)

# ============================================================
# PatchTST 改良版
# ============================================================
class PatchTST(nn.Module):
    def __init__(
        self,
        in_dim,
        patch_len=96,
        d_model=512,
        nhead=8,
        layers=4
    ):
        super().__init__()

        self.revin = RevIN(in_dim)

        self.patch = PatchEmbedding(
            in_dim,
            patch_len,
            d_model
        )

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            batch_first=True
        )

        self.encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=layers
        )

        self.head = nn.Linear(
            d_model,
            PRED_LEN
        )

    def forward(self, x):

        # -----------------------
        # 直前値保存（baseline維持）
        # -----------------------
        last_value = x[:, -1, target_idx]

        # -----------------------
        # RevIN 正規化（入力安定化）
        # -----------------------
        x = self.revin(x, "norm")

        # -----------------------
        # Patch + Transformer
        # -----------------------
        x = self.patch(x)
        x = self.encoder(x)

        # -----------------------
        # mean pooling廃止
        # -----------------------
        x = x[:, -1]

        # -----------------------
        # 予測
        # -----------------------
        x = self.head(x)

        # -----------------------
        # Residual接続
        # -----------------------
        x = x + last_value.unsqueeze(-1)

        return x

# ============================================================
# モデル
# ============================================================
model = PatchTST(
    in_dim=len(df.columns)
).to(device)

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=1e-4
)

loss_fn = nn.MSELoss()

# ============================================================
# 学習
# ============================================================
EPOCHS = 70

for epoch in range(EPOCHS):

    model.train()
    total_loss = 0

    for x, y in tqdm(
        train_loader,
        desc=f"Epoch {epoch+1}"
    ):
        x = x.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        out = model(x)

        loss = loss_fn(out, y)
        loss.backward()

        optimizer.step()

        total_loss += loss.item() * x.size(0)

    print(
        f"Epoch {epoch+1} Loss: "
        f"{total_loss / len(train_loader.dataset):.4f}"
    )

# ============================================================
# 評価
# ============================================================
def evaluate(loader):

    model.eval()
    preds, trues = [], []

    with torch.no_grad():
        for x, y in loader:

            x = x.to(device)
            out = model(x)

            preds.append(out.cpu().numpy())
            trues.append(y.numpy())

    preds = np.concatenate(preds).flatten()
    trues = np.concatenate(trues).flatten()

    mae  = mean_absolute_error(trues, preds)
    rmse = mean_squared_error(trues, preds) ** 0.5

    return mae, rmse

mae, rmse = evaluate(test_loader)

print(f"\nTest MAE : {mae:.4f}")
print(f"Test RMSE: {rmse:.4f}")

# ============================================================
# 可視化（逆標準化）
# ============================================================
x, y = next(iter(test_loader))
x = x.to(device)

with torch.no_grad():
    pred = model(x[:1])

mean = scaler.mean_[target_idx]
std  = scaler.scale_[target_idx]

true_plot = y[0].numpy() * std + mean
pred_plot = pred[0].cpu().numpy() * std + mean

plt.figure(figsize=(12, 5))

plt.plot(true_plot, label="True")
plt.plot(pred_plot, label="Pred")

plt.legend()
plt.title("PatchTST + RevIN Improved Forecast")
plt.show()
# Out:
# Epoch 1: 100%|██████████| 742/742 [00:12<00:00, 58.53it/s]
# Epoch 1 Loss: 0.3239
# Epoch 2: 100%|██████████| 742/742 [00:12<00:00, 61.51it/s]
# Epoch 2 Loss: 0.2876
# Epoch 3: 100%|██████████| 742/742 [00:12<00:00, 61.80it/s]
# Epoch 3 Loss: 0.2733
# Epoch 4: 100%|██████████| 742/742 [00:12<00:00, 61.80it/s]
# Epoch 4 Loss: 0.2614
# Epoch 5: 100%|██████████| 742/742 [00:12<00:00, 61.30it/s]
# Epoch 5 Loss: 0.2497
# Epoch 6: 100%|██████████| 742/742 [00:12<00:00, 61.47it/s]
# Epoch 6 Loss: 0.2407
# Epoch 7: 100%|██████████| 742/742 [00:12<00:00, 61.69it/s]
# Epoch 7 Loss: 0.2311
# Epoch 8: 100%|██████████| 742/742 [00:12<00:00, 61.30it/s]
# Epoch 8 Loss: 0.2191
# Epoch 9: 100%|██████████| 742/742 [00:12<00:00, 61.61it/s]
# Epoch 9 Loss: 0.2157
# Epoch 10: 100%|██████████| 742/742 [00:12<00:00, 61.62it/s]
# Epoch 10 Loss: 0.2101
# Epoch 11: 100%|██████████| 742/742 [00:12<00:00, 61.41it/s]
# Epoch 11 Loss: 0.2059
# Epoch 12: 100%|██████████| 742/742 [00:12<00:00, 61.82it/s]
# Epoch 12 Loss: 0.2026
# Epoch 13: 100%|██████████| 742/742 [00:11<00:00, 61.89it/s]
# Epoch 13 Loss: 0.1954
# Epoch 14: 100%|██████████| 742/742 [00:11<00:00, 61.87it/s]
# Epoch 14 Loss: 0.1874
# Epoch 15: 100%|██████████| 742/742 [00:12<00:00, 61.58it/s]
# Epoch 15 Loss: 0.1835
# Epoch 16: 100%|██████████| 742/742 [00:12<00:00, 61.74it/s]
# Epoch 16 Loss: 0.1804
# Epoch 17: 100%|██████████| 742/742 [00:12<00:00, 61.38it/s]
# Epoch 17 Loss: 0.1763
# Epoch 18: 100%|██████████| 742/742 [00:12<00:00, 61.58it/s]
# Epoch 18 Loss: 0.1689
# Epoch 19: 100%|██████████| 742/742 [00:12<00:00, 61.41it/s]
# Epoch 19 Loss: 0.1598
# Epoch 20: 100%|██████████| 742/742 [00:12<00:00, 61.62it/s]
# Epoch 20 Loss: 0.1563
# Epoch 21: 100%|██████████| 742/742 [00:12<00:00, 61.77it/s]
# Epoch 21 Loss: 0.1537
# Epoch 22: 100%|██████████| 742/742 [00:12<00:00, 61.82it/s]
# Epoch 22 Loss: 0.1459
# Epoch 23: 100%|██████████| 742/742 [00:11<00:00, 61.94it/s]
# Epoch 23 Loss: 0.1422
# Epoch 24: 100%|██████████| 742/742 [00:12<00:00, 61.76it/s]
# Epoch 24 Loss: 0.1378
# Epoch 25: 100%|██████████| 742/742 [00:11<00:00, 61.90it/s]
# Epoch 25 Loss: 0.1326
# Epoch 26: 100%|██████████| 742/742 [00:11<00:00, 62.19it/s]
# Epoch 26 Loss: 0.1282
# Epoch 27: 100%|██████████| 742/742 [00:11<00:00, 62.13it/s]
# Epoch 27 Loss: 0.1215
# Epoch 28: 100%|██████████| 742/742 [00:12<00:00, 61.81it/s]
# Epoch 28 Loss: 0.1205
# Epoch 29: 100%|██████████| 742/742 [00:12<00:00, 61.67it/s]
# Epoch 29 Loss: 0.1143
# Epoch 30: 100%|██████████| 742/742 [00:12<00:00, 61.43it/s]
# Epoch 30 Loss: 0.1087
# Epoch 31: 100%|██████████| 742/742 [00:12<00:00, 61.34it/s]
# Epoch 31 Loss: 0.1037
# Epoch 32: 100%|██████████| 742/742 [00:12<00:00, 61.79it/s]
# Epoch 32 Loss: 0.1003
# Epoch 33: 100%|██████████| 742/742 [00:12<00:00, 61.30it/s]
# Epoch 33 Loss: 0.0953
# Epoch 34: 100%|██████████| 742/742 [00:12<00:00, 61.65it/s]
# Epoch 34 Loss: 0.0919
# Epoch 35: 100%|██████████| 742/742 [00:12<00:00, 61.69it/s]
# Epoch 35 Loss: 0.0880
# Epoch 36: 100%|██████████| 742/742 [00:11<00:00, 61.87it/s]
# Epoch 36 Loss: 0.0826
# Epoch 37: 100%|██████████| 742/742 [00:12<00:00, 61.12it/s]
# Epoch 37 Loss: 0.0793
# Epoch 38: 100%|██████████| 742/742 [00:12<00:00, 61.21it/s]
# Epoch 38 Loss: 0.0769
# Epoch 39: 100%|██████████| 742/742 [00:12<00:00, 61.36it/s]
# Epoch 39 Loss: 0.0731
# Epoch 40: 100%|██████████| 742/742 [00:12<00:00, 61.71it/s]
# Epoch 40 Loss: 0.0685
# Epoch 41: 100%|██████████| 742/742 [00:12<00:00, 61.65it/s]
# Epoch 41 Loss: 0.0661
# Epoch 42: 100%|██████████| 742/742 [00:11<00:00, 61.98it/s]
# Epoch 42 Loss: 0.0650
# Epoch 43: 100%|██████████| 742/742 [00:12<00:00, 61.56it/s]
# Epoch 43 Loss: 0.0641
# Epoch 44: 100%|██████████| 742/742 [00:11<00:00, 61.88it/s]
# Epoch 44 Loss: 0.0645
# Epoch 45: 100%|██████████| 742/742 [00:12<00:00, 61.43it/s]
# Epoch 45 Loss: 0.0615
# Epoch 46: 100%|██████████| 742/742 [00:12<00:00, 61.41it/s]
# Epoch 46 Loss: 0.0580
# Epoch 47: 100%|██████████| 742/742 [00:12<00:00, 61.46it/s]
# Epoch 47 Loss: 0.0538
# Epoch 48: 100%|██████████| 742/742 [00:12<00:00, 61.61it/s]
# Epoch 48 Loss: 0.0513
# Epoch 49: 100%|██████████| 742/742 [00:12<00:00, 61.74it/s]
# Epoch 49 Loss: 0.0494
# Epoch 50: 100%|██████████| 742/742 [00:12<00:00, 61.52it/s]
# Epoch 50 Loss: 0.0500
# Epoch 51: 100%|██████████| 742/742 [00:12<00:00, 61.74it/s]
# Epoch 51 Loss: 0.0499
# Epoch 52: 100%|██████████| 742/742 [00:12<00:00, 61.58it/s]
# Epoch 52 Loss: 0.0457
# Epoch 53: 100%|██████████| 742/742 [00:11<00:00, 61.98it/s]
# Epoch 53 Loss: 0.0448
# Epoch 54: 100%|██████████| 742/742 [00:12<00:00, 61.55it/s]
# Epoch 54 Loss: 0.0440
# Epoch 55: 100%|██████████| 742/742 [00:12<00:00, 61.73it/s]
# Epoch 55 Loss: 0.0415
# Epoch 56: 100%|██████████| 742/742 [00:12<00:00, 61.57it/s]
# Epoch 56 Loss: 0.0405
# Epoch 57: 100%|██████████| 742/742 [00:12<00:00, 61.62it/s]
# Epoch 57 Loss: 0.0405
# Epoch 58: 100%|██████████| 742/742 [00:12<00:00, 60.92it/s]
# Epoch 58 Loss: 0.0402
# Epoch 59: 100%|██████████| 742/742 [00:12<00:00, 61.25it/s]
# Epoch 59 Loss: 0.0372
# Epoch 60: 100%|██████████| 742/742 [00:12<00:00, 61.23it/s]
# Epoch 60 Loss: 0.0367
# Epoch 61: 100%|██████████| 742/742 [00:12<00:00, 61.49it/s]
# Epoch 61 Loss: 0.0354
# Epoch 62: 100%|██████████| 742/742 [00:12<00:00, 61.31it/s]
# Epoch 62 Loss: 0.0327
# Epoch 63: 100%|██████████| 742/742 [00:12<00:00, 61.62it/s]
# Epoch 63 Loss: 0.0318
# Epoch 64: 100%|██████████| 742/742 [00:12<00:00, 61.60it/s]
# Epoch 64 Loss: 0.0331
# Epoch 65: 100%|██████████| 742/742 [00:12<00:00, 61.67it/s]
# Epoch 65 Loss: 0.0314
# Epoch 66: 100%|██████████| 742/742 [00:12<00:00, 61.38it/s]
# Epoch 66 Loss: 0.0310
# Epoch 67: 100%|██████████| 742/742 [00:11<00:00, 61.90it/s]
# Epoch 67 Loss: 0.0321
# Epoch 68: 100%|██████████| 742/742 [00:12<00:00, 61.77it/s]
# Epoch 68 Loss: 0.0321
# Epoch 69: 100%|██████████| 742/742 [00:12<00:00, 61.37it/s]
# Epoch 69 Loss: 0.0306
# Epoch 70: 100%|██████████| 742/742 [00:12<00:00, 61.31it/s]
# Epoch 70 Loss: 0.0290
#
# Test MAE : 0.4690
# Test RMSE: 0.5954

# %%
# # モデル保存
# SAVE_PATH = "../m2.pth"

# torch.save(model.state_dict(), SAVE_PATH)
# print("Model saved to", SAVE_PATH)
